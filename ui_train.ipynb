# %%
import os
import sys
import pathlib
project_root = os.path.abspath("../")
sys.path.append(project_root)
import random
import time
from game.infantry import Infantry,ACTION
from game.tank import *
from game.panal import *
pygame.init()


def get_nearby(infantry_units, unit):
    min_distance = 100
    target_infantry = None
    for infantry in infantry_units:
        distance = abs(infantry.x - unit.x) + abs(infantry.y - unit.y)
        if distance < min_distance and infantry.hp > 0:
            min_distance = distance
            target_infantry = infantry
    return (target_infantry.x, target_infantry.y)


def transform_state(unit, tank):
    dx = tank.x - unit.x
    dy = tank.y - unit.y
    return (dx,dy,unit.hp)
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.16)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
class QLearningAgent:
    def __init__(self, env):
        self.env = env
        self.q_table = self.create_q_table()
        self.alpha = 0.1
        self.gamma = 0.99
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995

    def get_q_value(self, state, action):
        if abs(state[0]) > 20 and abs(state[1]) > 20 :
            state = (int(state[0]/abs(state[0])*20),int(state[1]/abs(state[1])*20),state[2])
        elif abs(state[0]) > 20:
            state = (int(state[0]/abs(state[0])*20),state[1],state[2])
        elif abs(state[1]) > 20:
            state = (state[0],int(state[1]/abs(state[1])*20),state[2])
        return self.q_table.get(state).get(action)

    def choose_action(self, state):
        if random.uniform(0, 1) < self.epsilon:
            return random.choice(ACTION)
        else:
            q_values = [self.get_q_value(state, action) for action in ACTION]
            max_q = max(q_values)
            best_actions = [a for a, q in zip(ACTION, q_values) if q == max_q]
            return random.choice(best_actions)

    def update_q_table(self, state, action, reward, new_state):
        current_q = self.get_q_value(state, action)
        future_q = max([self.get_q_value(new_state, a) for a in ACTION])
        new_q = current_q + self.alpha * (reward + self.gamma * future_q - current_q)
        self.q_table[state][action] = new_q

    def decay_epsilon(self):
        self.epsilon = max(self.epsilon * self.epsilon_decay, self.epsilon_min)
        
    def create_q_table(self):
        #如果q_table.pkl存在，则加载,使用pathlib
        import pickle
        if pathlib.Path('q_table.pkl').exists():
            print('load q_table.pkl')
            with open('q_table.pkl', 'rb') as f:
                q_table = pickle.load(f)
            return q_table
        state = []
        for i in range(-20, 20 + 1):
            for j in range(-20, 20  + 1):
                state.append((i, j))
        result = {}
        for i in state:
            for j in [0,2,4,6,8]:
                result[(i[0],i[1],j)] = {}
                for k in ACTION:
                    result[(i[0], i[1], j)][k] = 0
        return result

# %%
class Environment:
    def __init__(self):
        self.game_end = False
        self.player_units = [Infantry(random.randint(0, BOARD_WIDTH // 2), random.randint(0, BOARD_HEIGHT)) for _ in
                        range(10)]
        self.tank = Tank(BOARD_WIDTH - 5, BOARD_HEIGHT // 2)
        self.tank_ai = TankAI(self.tank, None)
        self.states = []
        self.screen = ui_init()
        for i in self.player_units:
            self.states.append(transform_state(i,self.tank))
        
    def show_state(self):
        self.screen.fill((0, 0, 0))
        # 绘制网格
        for x in range(BOARD_WIDTH):
            for y in range(BOARD_HEIGHT):
                rect = pygame.Rect(x * CELL_WIDTH, y * CELL_HEIGHT, CELL_WIDTH, CELL_HEIGHT)
                pygame.draw.rect(self.screen, "#2F4F4F", rect, 1)
                
        # 绘制单位
        for infantry in self.player_units:
            rect = pygame.Rect(infantry.x * CELL_WIDTH, infantry.y * CELL_HEIGHT, CELL_WIDTH, CELL_HEIGHT)
            if infantry.hp <= 0:
                continue
            if infantry.selected:
                pygame.draw.rect(self.screen, GREEN, rect)
            elif not infantry.moved:
                pygame.draw.rect(self.screen, BLUE, rect)
            else:
                pygame.draw.rect(self.screen, "#4444AA", rect)
            pygame.draw.rect(self.screen, BLACK, rect, 1)

        # 绘制坦克
        tank_rect = pygame.Rect(
            self.tank.x * CELL_WIDTH - CELL_WIDTH,
            self.tank.y * CELL_HEIGHT - CELL_HEIGHT,
            CELL_WIDTH * self.tank.size[0],
            CELL_HEIGHT * self.tank.size[1]
        )
        pygame.draw.rect(self.screen, RED, tank_rect)
        pygame.draw.rect(self.screen, BLACK, tank_rect, 1)

        draw_hp_panel(self.tank,self.player_units,self.screen)
        pygame.display.flip()

    def reset(self):
        self.game_end = False
        self.player_units = [Infantry(random.randint(0, BOARD_WIDTH // 2), random.randint(0, BOARD_HEIGHT)) for _ in
                        range(10)]
        self.tank = Tank(BOARD_WIDTH - 5, BOARD_HEIGHT // 2)
        self.tank_ai = TankAI(self.tank, None)
        self.show_state()
        

    def step(self, actions,use_screen = False):
        rewards = [0 for i in range(10)]
        for index,unit in enumerate(self.player_units):
            unit.move(actions[index][0],actions[index][1])

        under_crush_units = []
        self.tank_ai.decide_movement(self.player_units)
        for x, y in self.tank.route:
            for i in self.tank.crush(x, y, self.player_units):
                #被碾压了但是未被记录
                if i not in under_crush_units:
                    under_crush_units.append(i)
        for index in under_crush_units:
            rewards[index] -= 35
        self.tank.route = []
        self.tank_ai.decide_attack(self.player_units)
        for index,infantry in enumerate(self.player_units):
            if infantry.hp <= 0:
                continue
            if abs(infantry.x - self.tank.x) + abs(infantry.y - self.tank.y) <= infantry.range:
                self.tank.hp -= infantry.attack_power
                # 给予奖励
                rewards[index] += 6

            else:
                rewards[index] -= 1
                # 给予副奖励
                pass
        self.show_state()
        pygame.display.flip()
        if use_screen:
            game_end = check_victory_conditions(self.tank, self.player_units, self.screen)
        else:
            game_end = check_victory_conditions(self.tank, self.player_units)
        pygame.display.flip()
        self.states = []
        for i in self.player_units:
            self.states.append(transform_state(i,self.tank))
        if game_end:
            print(game_end)

        return self.states,rewards,game_end

# %% [markdown]
# # 正式训练代码

# %%
env = Environment()
agent = QLearningAgent(env)
num_episodes = 1000

for episode in range(num_episodes):
    # 重置环境
    env.reset()
    total_reward = 0

    while True:
        # 获取当前状态
        current_states = [transform_state(unit, env.tank) for unit in env.player_units]
        actions = []
        
        # 选择动作
        for idx, state in enumerate(current_states):
            if state is not None:  # 确保状态合法
                # action = agent.q_learning_units[idx].choose_action(state)
                action = agent.choose_action(state)
                actions.append(action)
        
        # 执行动作并获取新状态和奖励
        next_states, rewards, done = env.step(actions,episode>600)
        
        # 更新Q表
        for idx, (state, action, reward, next_state) in enumerate(zip(current_states, actions, rewards, next_states)):
            if abs(state[0]) > 20 and abs(state[1]) > 20 :
                state = (int(state[0]/abs(state[0])*20),int(state[1]/abs(state[1])*20),state[2])
            elif abs(state[0]) > 20:
                state = (int(state[0]/abs(state[0])*20),state[1],state[2])
            elif abs(state[1]) > 20:
                state = (state[0],int(state[1]/abs(state[1])*20),state[2])
            agent.update_q_table(state, action, reward, next_state)
        
        total_reward += sum(rewards)

        # 检查游戏是否结束
        if done:
            # 打印训练信息
            print(f"Episode {episode + 1}: Total Reward = {total_reward}! ")
            break
        if episode > 600:
            time.sleep(0.5)

    # 衰减探索率
    agent.decay_epsilon()





# # 保存 Q 表
# with open('q_table.pkl', 'wb') as f:
#     pickle.dump(agent.q_table, f)
# Out:
# load q_table.pkl
# Player Loses!
# Episode 1: Total Reward = -169!
# Player Loses!
# Episode 2: Total Reward = -280!
# Player Loses!
# Episode 3: Total Reward = -453!
# Player Loses!
# Episode 4: Total Reward = -351!
# Player Loses!
# Episode 5: Total Reward = -198!
# Player Loses!
# Episode 6: Total Reward = -112!
# Player Loses!
# Episode 7: Total Reward = -293!
# Player Loses!
# Episode 8: Total Reward = -240!
# Player Loses!
# Episode 9: Total Reward = -360!
# Player Loses!
# Episode 10: Total Reward = -352!
# Player Loses!
# Episode 11: Total Reward = -415!
# Player Loses!
# Episode 12: Total Reward = -391!
# Player Loses!
# Episode 13: Total Reward = -311!
# Player Loses!
# Episode 14: Total Reward = -249!
# Player Loses!
# Episode 15: Total Reward = -349!
# Player Loses!
# Episode 16: Total Reward = -377!
# Player Loses!
# Episode 17: Total Reward = -392!
# Player Loses!
# Episode 18: Total Reward = -216!
# Player Loses!
# Episode 19: Total Reward = -186!
# Player Loses!
# Episode 20: Total Reward = -248!
# Player Loses!
# Episode 21: Total Reward = -255!
# Player Loses!
# Episode 22: Total Reward = -173!
# Player Loses!
# Episode 23: Total Reward = 8!
# Player Loses!
# Episode 24: Total Reward = -304!
# Player Loses!
# Episode 25: Total Reward = -205!
# Player Loses!
# Episode 26: Total Reward = -128!
# Player Loses!
# Episode 27: Total Reward = -99!
# Player Loses!
# Episode 28: Total Reward = -351!
# Player Loses!
# Episode 29: Total Reward = -279!
# Player Loses!
# Episode 30: Total Reward = -85!
# Player Loses!
# Episode 31: Total Reward = -292!
# Player Loses!
# Episode 32: Total Reward = -195!
# Player Loses!
# Episode 33: Total Reward = -415!
# Player Loses!
# Episode 34: Total Reward = -221!
# Player Loses!
# Episode 35: Total Reward = -123!
# Player Loses!
# Episode 36: Total Reward = -184!
# Player Loses!
# Episode 37: Total Reward = -322!
# Player Loses!
# Episode 38: Total Reward = -196!
# Player Loses!
# Episode 39: Total Reward = -31!
# Player Loses!
# Episode 40: Total Reward = -92!
# Player Loses!
# Episode 41: Total Reward = -276!
# Player Loses!
# Episode 42: Total Reward = -207!
# Player Loses!
# Episode 43: Total Reward = -23!
# Player Loses!
# Episode 44: Total Reward = -315!
# Player Loses!
# Episode 45: Total Reward = -154!
# Player Loses!
# Episode 46: Total Reward = -246!
# Player Loses!
# Episode 47: Total Reward = -81!
# Player Loses!
# Episode 48: Total Reward = -106!
# Player Loses!
# Episode 49: Total Reward = -106!
# Player Loses!
# Episode 50: Total Reward = -442!
# Player Loses!
# Episode 51: Total Reward = -294!
# Player Loses!
# Episode 52: Total Reward = -282!
# Player Loses!
# Episode 53: Total Reward = -430!
# Player Loses!
# Episode 54: Total Reward = -382!
# Player Loses!
# Episode 55: Total Reward = -301!
# Player Loses!
# Episode 56: Total Reward = -4!
# Player Loses!
# Episode 57: Total Reward = -91!
# Player Loses!
# Episode 58: Total Reward = -339!
# Player Loses!
# Episode 59: Total Reward = -41!
# Player Loses!
# Episode 60: Total Reward = -224!
# Player Loses!
# Episode 61: Total Reward = -201!
# Player Loses!
# Episode 62: Total Reward = -149!
# Player Loses!
# Episode 63: Total Reward = -238!
# Player Loses!
# Episode 64: Total Reward = -167!
# Player Loses!
# Episode 65: Total Reward = -178!
# Player Loses!
# Episode 66: Total Reward = -294!
# Player Loses!
# Episode 67: Total Reward = -128!
# Player Loses!
# Episode 68: Total Reward = -141!
# Player Loses!
# Episode 69: Total Reward = -176!
# Player Loses!
# Episode 70: Total Reward = -51!
# Player Loses!
# Episode 71: Total Reward = -71!
# Player Loses!
# Episode 72: Total Reward = -70!
# Player Loses!
# Episode 73: Total Reward = 21!
# Player Loses!
# Episode 74: Total Reward = -171!
# Player Loses!
# Episode 75: Total Reward = -274!
# Player Loses!
# Episode 76: Total Reward = -307!
# Player Loses!
# Episode 77: Total Reward = -104!
# Player Loses!
# Episode 78: Total Reward = -225!
# Player Loses!
# Episode 79: Total Reward = 55!
# Player Loses!
# Episode 80: Total Reward = 123!
# Player Loses!
# Episode 81: Total Reward = -5!
# Player Loses!
# Episode 82: Total Reward = 171!
# Player Loses!
# Episode 83: Total Reward = -126!
# Player Loses!
# Episode 84: Total Reward = -115!
# Player Loses!
# Episode 85: Total Reward = -301!
# Player Loses!
# Episode 86: Total Reward = -78!
# Player Loses!
# Episode 87: Total Reward = -112!
# Player Loses!
# Episode 88: Total Reward = -115!
# Player Loses!
# Episode 89: Total Reward = -123!
# Player Loses!
# Episode 90: Total Reward = -217!
# Player Loses!
# Episode 91: Total Reward = -78!
# Player Loses!
# Episode 92: Total Reward = -175!
# Player Loses!
# Episode 93: Total Reward = -158!
# Player Loses!
# Episode 94: Total Reward = 6!
# Player Loses!
# Episode 95: Total Reward = -144!
# Player Loses!
# Episode 96: Total Reward = -246!
# Player Loses!
# Episode 97: Total Reward = -79!
# Player Loses!
# Episode 98: Total Reward = -396!
# Player Loses!
# Episode 99: Total Reward = -177!
# Player Loses!
# Episode 100: Total Reward = -122!
# Player Loses!
# Episode 101: Total Reward = -219!
# Player Loses!
# Episode 102: Total Reward = -284!
# Player Loses!
# Episode 103: Total Reward = -113!
# Player Loses!
# Episode 104: Total Reward = -127!
# Player Loses!
# Episode 105: Total Reward = -144!
# Player Loses!
# Episode 106: Total Reward = -83!
# Player Loses!
# Episode 107: Total Reward = -144!
# Player Loses!
# Episode 108: Total Reward = -122!
# Player Loses!
# Episode 109: Total Reward = -122!
# Player Loses!
# Episode 110: Total Reward = -243!
# Player Loses!
# Episode 111: Total Reward = -236!
# Player Loses!
# Episode 112: Total Reward = -23!
# Player Loses!
# Episode 113: Total Reward = -174!
# Player Loses!
# Episode 114: Total Reward = 106!
# Player Loses!
# Episode 115: Total Reward = -250!
# Player Wins!
# Episode 241: Total Reward = 67!
# Player Loses!
# Episode 242: Total Reward = 115!
# Player Loses!
# Episode 243: Total Reward = 4!
# Player Loses!
# Episode 244: Total Reward = 71!
# Player Loses!
# Episode 245: Total Reward = 127!
# Player Loses!
# Episode 246: Total Reward = 60!
# Player Loses!
# Episode 247: Total Reward = -69!
# Player Loses!
# Episode 248: Total Reward = -141!
# Player Loses!
# Episode 249: Total Reward = 109!
# Player Loses!
# Episode 250: Total Reward = 8!
# Player Wins!
# Episode 251: Total Reward = 192!
# Player Loses!
# Episode 252: Total Reward = 186!
# Player Loses!
# Episode 253: Total Reward = -129!
# Player Loses!
# Episode 254: Total Reward = 24!
# Player Loses!
# Episode 255: Total Reward = 227!
# Player Loses!
# Episode 256: Total Reward = 38!
# Player Loses!
# Episode 257: Total Reward = 216!
# Player Loses!
# Episode 258: Total Reward = 130!
# Player Loses!
# Episode 259: Total Reward = -77!
# Player Wins!
# Episode 260: Total Reward = 250!
# Player Loses!
# Episode 261: Total Reward = 139!
# Player Loses!
# Episode 262: Total Reward = 200!
# Player Loses!
# Episode 263: Total Reward = 103!
# Player Loses!
# Episode 264: Total Reward = 143!
# Player Loses!
# Episode 265: Total Reward = -98!
# Player Loses!
# Episode 266: Total Reward = 5!
# Player Loses!
# Episode 267: Total Reward = 65!
# Player Loses!
# Episode 268: Total Reward = 146!
# Player Loses!
# Episode 269: Total Reward = 154!
# Player Loses!
# Episode 270: Total Reward = 221!
# Player Loses!
# Episode 271: Total Reward = -5!
# Player Loses!
# Episode 272: Total Reward = -81!
# Player Loses!
# Episode 273: Total Reward = 217!
# Player Loses!
# Episode 274: Total Reward = 59!
# Player Loses!
# Episode 275: Total Reward = 142!
# Player Loses!
# Episode 276: Total Reward = -109!
# Player Loses!
# Episode 277: Total Reward = 17!
# Player Loses!
# Episode 278: Total Reward = 223!
# Player Loses!
# Episode 279: Total Reward = 96!
# Player Wins!
# Episode 280: Total Reward = 281!
# Player Loses!
# Episode 281: Total Reward = 220!
# Player Loses!
# Episode 282: Total Reward = 67!
# Player Loses!
# Episode 283: Total Reward = 41!
# Player Loses!
# Episode 284: Total Reward = 203!
# Player Loses!
# Episode 285: Total Reward = -77!
# Player Loses!
# Episode 286: Total Reward = 86!
# Player Loses!
# Episode 287: Total Reward = -69!
# Player Loses!
# Episode 288: Total Reward = 129!
# Player Loses!
# Episode 289: Total Reward = 14!
# Player Wins!
# Episode 290: Total Reward = 295!
# Player Loses!
# Episode 291: Total Reward = 14!
# Player Loses!
# Episode 292: Total Reward = 54!
# Player Loses!
# Episode 293: Total Reward = 80!
# Player Loses!
# Episode 294: Total Reward = 233!
# Player Loses!
# Episode 295: Total Reward = 46!
# Player Loses!
# Episode 296: Total Reward = 53!
# Player Loses!
# Episode 297: Total Reward = -30!
# Player Wins!
# Episode 298: Total Reward = 225!
# Player Loses!
# Episode 299: Total Reward = 59!
# Player Loses!
# Episode 300: Total Reward = 231!
# Player Loses!
# Episode 301: Total Reward = 49!
# Player Loses!
# Episode 302: Total Reward = 7!
# Player Loses!
# Player Loses!
# Episode 553: Total Reward = 81!
# Player Wins!
# Episode 554: Total Reward = 325!
# Player Wins!
# Episode 555: Total Reward = 376!
# Player Loses!
# Episode 556: Total Reward = 195!
# Player Loses!
# Episode 557: Total Reward = 78!
# Player Loses!
# Episode 558: Total Reward = -2!
# Player Loses!
# Episode 559: Total Reward = 83!
# Player Loses!
# Episode 560: Total Reward = 140!
# Player Wins!
# Episode 561: Total Reward = 333!
# Player Wins!
# Episode 562: Total Reward = 278!
# Player Wins!
# Episode 563: Total Reward = 335!
# Player Wins!
# Episode 564: Total Reward = 303!
# Player Loses!
# Episode 565: Total Reward = 146!
# Player Loses!
# Episode 566: Total Reward = 165!
# Player Wins!
# Episode 567: Total Reward = 270!
# Player Loses!
# Episode 568: Total Reward = 159!
# Player Loses!
# Episode 569: Total Reward = 103!
# Player Loses!
# Episode 570: Total Reward = 187!
# Player Loses!
# Episode 571: Total Reward = 211!
# Player Loses!
# Episode 572: Total Reward = 174!
# Player Loses!
# Episode 573: Total Reward = 159!
# Player Wins!
# Episode 574: Total Reward = 304!
# Player Loses!
# Episode 575: Total Reward = 48!
# Player Loses!
# Episode 576: Total Reward = 216!
# Player Loses!
# Episode 577: Total Reward = 214!
# Player Loses!
# Episode 578: Total Reward = 83!
# Player Loses!
# Episode 579: Total Reward = 160!
# Player Loses!
# Episode 580: Total Reward = 237!
# Player Loses!
# Episode 581: Total Reward = 125!
# Player Wins!
# Episode 582: Total Reward = 327!
# Player Wins!
# Episode 583: Total Reward = 292!
# Player Wins!
# Episode 584: Total Reward = 235!
# Player Wins!
# Episode 585: Total Reward = 298!
# Player Loses!
# Episode 586: Total Reward = 208!
# Player Loses!
# Episode 587: Total Reward = 191!
# Player Wins!
# Episode 588: Total Reward = 363!
# Player Loses!
# Episode 589: Total Reward = 218!
# Player Wins!
# Episode 590: Total Reward = 220!
# Player Loses!
# Episode 591: Total Reward = 139!
# Player Loses!
# Episode 592: Total Reward = 109!
# Player Loses!
# Episode 593: Total Reward = 196!
# Player Wins!
# Episode 594: Total Reward = 247!
# Player Wins!
# Episode 595: Total Reward = 231!
# Player Loses!
# Episode 596: Total Reward = 190!
# Player Wins!
# Episode 597: Total Reward = 268!
# Player Loses!
# Episode 598: Total Reward = 269!
# Player Wins!
# Episode 599: Total Reward = 391!
# Player Loses!
# Episode 600: Total Reward = 132!
# Player Loses!
# Episode 601: Total Reward = 95!
# Player Wins!
# Episode 602: Total Reward = 175!
# Player Loses!
# Episode 603: Total Reward = 212!
# Player Wins!
# Episode 604: Total Reward = 308!
# Player Loses!
# Episode 605: Total Reward = 198!
# Player Wins!
# Episode 606: Total Reward = 294!
# Player Wins!
# Episode 607: Total Reward = 211!
# Player Wins!
# Episode 608: Total Reward = 321!
# Player Wins!
# Episode 609: Total Reward = 341!
# Player Loses!
# Episode 610: Total Reward = 74!
# Player Loses!
# Episode 611: Total Reward = 138!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[192], line 43
#      41         break
#      42     if episode > 600:
# ---> 43         time.sleep(0.5)
#      45 # 衰减探索率
#      46 agent.decay_epsilon()
#
# KeyboardInterrupt:
